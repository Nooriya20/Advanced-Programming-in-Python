# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import pandas
data = pandas.read_csv("Iris.csv")
res = sn.kdeplot(data['SepalLengthCm'],color='pink',shade=True)
plt.show()

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import pandas
data = pandas.read_csv("Iris.csv")
res = sn.kdeplot(data['SepalWidthCm'],color='magenta',shade=True)
plt.show()

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import pandas
data2 = pandas.read_csv("Iris.csv")
re = sn.kdeplot(data2['PetalLengthCm'],color='skyblue',shade=True)
plt.show()

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import pandas
data = pandas.read_csv("Iris.csv")
res = sn.kdeplot(data['PetalWidthCm'],color='purple',shade=True)
plt.show()

# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  
iris = datasets.load_iris()
  
iris_df = pd.DataFrame(iris.data, columns=['Sepal_Length','Sepal_Width', 'Patal_Length', 'Petal_Width'])
  
iris_df['Target'] = iris.target
  
iris_df['Target'].replace([2], 'Iris_Virginica', inplace=True)
  
sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Virginica'),'Sepal_Length'], color='b', 
            shade=True, Label='Iris_Virginica')
  
plt.xlabel('Iris Virginica Sepal Length')
plt.ylabel('Probability Density')
# Out:
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# Text(0, 0.5, 'Probability Density')

# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  
iris = datasets.load_iris()
  
iris_df = pd.DataFrame(iris.data, columns=['Sepal_Length','Sepal_Width', 'Patal_Length', 'Petal_Width'])
  
iris_df['Target'] = iris.target
  
iris_df['Target'].replace([1], 'Iris_Vercicolor', inplace=True)
  
sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Vercicolor'),'Sepal_Length'], color='g', 
            shade=True, Label='Iris_Vercicolor')
  
plt.xlabel('Iris Vercicolor Sepal Length')
plt.ylabel('Probability Density')
# Out:
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# Text(0, 0.5, 'Probability Density')

# %%
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  
iris = datasets.load_iris()
  
iris_df = pd.DataFrame(iris.data, columns=['Sepal_Length','Sepal_Width', 'Patal_Length', 'Petal_Width'])
  
iris_df['Target'] = iris.target
  
iris_df['Target'].replace([0], 'Iris_Setosa', inplace=True)
  
sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Setosa'),'Sepal_Length'], color='m', 
            shade=True, Label='Iris_Setosa')
  
plt.xlabel('Iris Setosa Sepal Length')
plt.ylabel('Probability Density')
# Out:
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:949: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = self.ax.fill_between([], [], **plot_kws)
# C:\Users\Nooriya\anaconda3\lib\site-packages\seaborn\distributions.py:992: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   artist = ax.fill_between(
# Text(0, 0.5, 'Probability Density')
