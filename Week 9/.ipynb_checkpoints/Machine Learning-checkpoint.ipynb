# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Iris.csv')
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.notnull()
# Out:
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    True           True          True           True          True     True
# 1    True           True          True           True          True     True
# 2    True           True          True           True          True     True
# 3    True           True          True           True          True     True
# 4    True           True          True           True          True     True
# ..    ...            ...           ...            ...           ...      ...
# 145  True           True          True           True          True     True
# 146  True           True          True           True          True     True
# 147  True           True          True           True          True     True
# 148  True           True          True           True          True     True
# 149  True           True          True           True          True     True
#
# [150 rows x 6 columns]

# %%
import pandas as pd 
data = pd.read_csv("Iris.csv") 
bool_series = pd.isnull(data["SepalLengthCm"]) 
data[bool_series]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df=pd.read_csv('Iris.csv')
df.head(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import pandas as pd
data = pd.read_csv("Iris.csv")
data.set_index("Id", inplace = True)
data.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
Id = df['Id']
Id
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
SepalLengthCm = df['SepalLengthCm']
SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
SepalWidthCm = df['SepalWidthCm']
SepalWidthCm
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
PetalLengthCm = df['PetalLengthCm']
PetalLengthCm
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
PetalWidthCm = df['PetalWidthCm']
PetalWidthCm
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64

# %%
Species = df['Species']
Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
import numpy as np

# %%
SepalLength_mean = np.mean(SepalLengthCm)
print('SepalLengthCm',SepalLength_mean)
SepalLength_median = np.median(SepalLengthCm)
print (SepalLength_median)
SepalLength_standardDeviation = np.std(SepalLengthCm)
print (SepalLength_standardDeviation)
SepalLength_variance = np.var(SepalLengthCm)
print (SepalLength_variance)
# Out:
# SepalLengthCm 5.843333333333335
# 5.8
# 0.8253012917851409
# 0.6811222222222222

# %%
SepalWidth_mean = np.mean(SepalWidthCm)
print('SepalWidthCm' ,SepalWidth_mean)
SepalWidth_median = np.median(SepalWidthCm)
print ( SepalWidth_median)
SepalWidth_standardDeviation = np.std(SepalWidthCm)
print (SepalWidth_standardDeviation)
SepalWidth_variance = np.var(SepalWidthCm)
print (SepalWidth_variance)
# Out:
# SepalWidthCm 3.0540000000000007
# 3.0
# 0.4321465800705435
# 0.1867506666666667

# %%
PetalLength_mean = np.mean(PetalLengthCm)
print('PetalLengthCm',PetalLength_mean)
PetalLength_median = np.median(PetalLengthCm)
print('PetalLengthCm',PetalLength_median)
PetalLength_variance = np.var(PetalLengthCm)
print('PetalLengthCm',PetalLength_variance)
PetalLength_standardDeviation = np.std(PetalLengthCm)
print('PetalLengthCm',PetalLength_standardDeviation)
# Out:
# PetalLengthCm 3.7586666666666693
# PetalLengthCm 4.35
# PetalLengthCm 3.0924248888888854
# PetalLengthCm 1.7585291834055201

# %%
PetalWidth_mean = np.mean(PetalWidthCm)
print('PetalWidthCm',PetalWidth_mean)
PetalWidth_median = np.median(PetalWidthCm)
print('PetalWidthCm',PetalWidth_median)
PetalWidth_variance = np.var(PetalWidthCm)
print('PetalWidthCm',PetalWidth_variance)
PetalWidth_standardDeviation = np.var(PetalWidthCm)
print('PetalWidthCm',PetalWidth_standardDeviation)
# Out:
# PetalWidthCm 1.1986666666666672
# PetalWidthCm 1.3
# PetalWidthCm 0.5785315555555559
# PetalWidthCm 0.5785315555555559

# %%
df.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x = df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]

# %%
print(x.head(150))
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y = df[["Species"]]

# %%
print(y.head(150))
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train = x[:130]
y_train = y[:130]

x_test = x[130:]
y_test = y[130:]

# %%
x_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 125            7.2           3.2            6.0           1.8
# 126            6.2           2.8            4.8           1.8
# 127            6.1           3.0            4.9           1.8
# 128            6.4           2.8            5.6           2.1
# 129            7.2           3.0            5.8           1.6
#
# [130 rows x 4 columns]

# %%
y_train
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
#
# [130 rows x 1 columns]

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 130            7.4           2.8            6.1           1.9
# 131            7.9           3.8            6.4           2.0
# 132            6.4           2.8            5.6           2.2
# 133            6.3           2.8            5.1           1.5
# 134            6.1           2.6            5.6           1.4
# 135            7.7           3.0            6.1           2.3
# 136            6.3           3.4            5.6           2.4
# 137            6.4           3.1            5.5           1.8
# 138            6.0           3.0            4.8           1.8
# 139            6.9           3.1            5.4           2.1
# 140            6.7           3.1            5.6           2.4
# 141            6.9           3.1            5.1           2.3
# 142            5.8           2.7            5.1           1.9
# 143            6.8           3.2            5.9           2.3
# ...

# %%
y_test
# Out:
#             Species
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
print("\n train data:")
print(x_train)
print(y_train)
print("\n test data:")
print(x_test)
print(y_test)
# Out:
#  train data:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 125            7.2           3.2            6.0           1.8
# 126            6.2           2.8            4.8           1.8
# 127            6.1           3.0            4.9           1.8
# 128            6.4           2.8            5.6           2.1
# 129            7.2           3.0            5.8           1.6
#
# [130 rows x 4 columns]
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 125  Iris-virginica
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
print("Response for test dataset:")
y_pred = knn.predict(x_test)
print(y_pred)
# Out:
# Response for test dataset:
# ['Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']
# C:\Users\Nooriya\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
y_test
# Out:
#             Species
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
